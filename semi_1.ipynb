# %%
api key
e734d2ae27450ddcc20a5a8eb5d46c107c28f88a



get함수
    - https://opendart.fss.or.kr/api/fnlttMultiAcnt.json

다중회사 주요계정 개발 가이드 (회사 재무표)
고유번호 개발 가이드 (회사코드 찾기)
    - https://opendart.fss.or.kr/api/corpCode.json
# Out:
#   File "<ipython-input-18-4261e1fb097d>", line 1
#     api key
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
from bs4 import BeautifulSoup
import json

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
base_url = 'https://opendart.fss.or.kr/api/fnlttMultiAcnt.json'
crtfc_key = 'e734d2ae27450ddcc20a5a8eb5d46c107c28f88a'
corp_code = '00334624'
bsns_year = '2021'
reprt_code = '11012'

# %% [markdown]
# 	https://opendart.fss.or.kr/api/fnlttMultiAcnt.json?
#         crtfc_key=xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#         &corp_code=00356370,00334624&bsns_year=2018&reprt_code=11011

# %%
request_url = base_url + '11013' + 'crtfc_key='+crtfc_key+'&corp_code='+corp_code+\
    '&bsns_year='+bsns_year + '&reprt_code='+reprt_code
print(request_url)
# Out:
# https://opendart.fss.or.kr/api/fnlttMultiAcnt.json11013crtfc_key=e734d2ae27450ddcc20a5a8eb5d46c107c28f88a&corp_code=00334624&bsns_year=2021&reprt_code=11012

# %%
response = requests.get(request_url).content
data = json.loads(response)

# %%
# Out:
# <meta content="0;url=http://opendart.fss.or.kr/code404.html" http-equiv="refresh"/>

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-dbd883db58b7> in <module>
# ----> 1 print(data)
#
# NameError: name 'data' is not defined
